# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/spotify_listening_behavior_500k.csv')

# %%
print(f"Collected length {len(df)} of douments")
# Out:
# Collected length 500000 of douments

# %%
print(df['favorite_genre'].value_counts())
# Out:
# favorite_genre
# Pop          90139
# Hip-Hop      74980
# Rock         64857
# EDM          60081
# Indie        49993
# R&B          39909
# K-Pop        35042
# Latin        30070
# Jazz         19966
# Classical    15103
# Lo-fi         9937
# Country       9923
# Name: count, dtype: int64

# %%
print(df['subscription_type'].value_counts())
# Out:
# subscription_type
# Premium    324904
# Free       175096
# Name: count, dtype: int64

# %%
print(df['country'].value_counts())
# Out:
# country
# USA          62915
# India        62801
# France       62730
# Germany      62564
# Brazil       62371
# Canada       62275
# UK           62249
# Australia    62095
# Name: count, dtype: int64

# %%
print(df['device_type'].value_counts())
# Out:
# device_type
# Mobile           125345
# Smart Speaker    125021
# Desktop          124924
# Tablet           124710
# Name: count, dtype: int64

# %%
print(df['timestamp'].value_counts())
# Out:
# timestamp
# 2025-05-30 21:40:06.223901    1
# 2025-09-08 19:33:15.136887    1
# 2025-07-03 01:03:54.802512    1
# 2025-05-22 13:12:10.718257    1
# 2026-01-24 06:45:26.807750    1
#                              ..
# 2026-02-27 08:15:05.197064    1
# 2025-06-15 18:24:38.107227    1
# 2025-09-04 03:27:42.766725    1
# 2025-06-13 13:57:53.119062    1
# 2026-03-02 19:14:29.895252    1
# Name: count, Length: 500000, dtype: int64

# %%
print(f"Average playlist count: {df['playlist_count'].mean():.0f}")
# Out:
# Average playlist count: 20

# %%
print(f"Average liked songs: {df['liked_songs'].mean():.0f}")
# Out:
# Average liked songs: 200
